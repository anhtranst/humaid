# %% [markdown]
# # HumAID — Zero-shot Classification (Filtered Labels, Batch API, and Auto-Report)
#
# This notebook runs **zero-shot tweet classification** for the HumAID events using ChatGPT, **restricting choices to only the labels that *actually exist* in each event’s ground truth** (“filtered labels”). It submits jobs via the **/v1/chat/completions Batch API**, enforces **token budgeting** across events, and produces per-event **analysis artifacts + an HTML results index**.
#
# ---
#
# ## What this notebook does
#
# **Pipeline overview**
# 1. **Discover datasets** under `Dataset/HumAID/<event>/<event>_{train|dev|test}.tsv`.
# 2. **Token budgeting** (`budget.build_token_index`): estimates total tokens per event (prompt + output).
# 3. **Key routing**
#    - Small events → `OPENAI_API_KEY_1` (Tier-1).
#    - Large events (over cap) → `OPENAI_API_KEY_2` (Alt key).
# 4. **Filtered-labels requests** (`batch.build_requests_jsonl_S`)
#    - Extracts **CURRENT_LABELS** = labels present in the event’s ground truth.
#    - Builds a **strict JSON schema** enumerating only those labels.
#    - Prompts the model to choose **exactly one** label from that list.
# 5. **Single-label bypass** (`runner.run_experiment`)
#    - If an event has **exactly one** valid label, **no API call is made**.
#    - We generate predictions locally (all rows → that label) and still produce full analysis.
# 6. **Batch submission** (multi-label events): upload JSONL → create batch → wait → download outputs.
# 7. **Parse + save predictions** and run **evaluation** (`eval.analyze_and_export_mistakes`):
#    - Scope = **truth-only** (metrics exclude labels not present in the event).
#    - Records `invalid_pred_outside_truth` for sanity checks.
#    - Exports confusion matrices, per-class metrics, mistakes CSV, and `summary.json`.
# 8. **Build HTML index** (`report.build_results_index`): interactive, sortable tables, best-run badges.
#
# ---
#
# ## Why filtered labels?
#
# - Some events miss one or more classes entirely. Allowing the global label set would invite **hallucinated labels** and distort metrics.
# - Restricting to the **ground-truth present labels** aligns the task with real data and keeps metrics meaningful.
# - We still **count** any model outputs outside the event’s label set in `invalid_pred_outside_truth` for QA.
#
# ---
#
# ## Important settings (edit above as needed)
#
# - **MODEL**: `gpt-4o-mini`
# - **RULES**: `RULES_1` (see `rules.py`)
# - **TAG**: appended to the run directory for provenance (e.g., `modeS-RULES1-filtered`)
# - **DRYRUN_N**: quick sync sanity check before batching
# - **POLL_SECS**: polling interval for batch completion
# - **BATCH_TOKEN_LIMIT**: per-key token budget (e.g., Tier-1 cap)
# - **MAX_OUTPUT_TOKENS**: must match batch builder’s `max_tokens` (default 40)
#
# Environment:
# - `.env` must provide `OPENAI_API_KEY_1` and (optionally) `OPENAI_API_KEY_2`.
#
# ---

# %% [markdown]
# # 0) Setup

# %%
from pathlib import Path
import pandas as pd
from dotenv import load_dotenv; load_dotenv()

from humaidclf import run_experiment
from humaidclf import build_token_index               # from budget.py
from humaidclf.batch import use_api_key_env           # context manager for key switching
from rules import RULES_1

# --- config ---
BASE = Path("Dataset/HumAID")
SPLITS = ["test"]             # or ["train","dev","test"]
MODEL = "gpt-4o-mini"
RULES = RULES_1
TAG = "modeS-RULES1-filtered"
DRYRUN_N = 20
POLL_SECS = 300
DO_ANALYSIS = True
OUT_ROOT = "runs"

BATCH_TOKEN_LIMIT = 2_000_000  # Tier-1 cap
SAFETY_MARGIN = 0.90           # 10% headroom
MAX_OUTPUT_TOKENS = 40

# %% [markdown]
# # 1) Discover datasets (events/splits)

# %%
# --- discover datasets ---
def discover_tsvs(base: Path, splits: list[str]):
    items = []
    for event_dir in sorted([p for p in base.iterdir() if p.is_dir()]):
        event = event_dir.name
        for split in splits:
            tsv = event_dir / f"{event}_{split}.tsv"
            if tsv.exists():
                items.append({"event": event, "split": split, "tsv": str(tsv)})
    return pd.DataFrame(items)

df_sources = discover_tsvs(BASE, SPLITS)

# --- token budgeting ---
token_index = build_token_index(
    df_sources,
    model=MODEL,
    rules_text=RULES,
    batch_token_limit=BATCH_TOKEN_LIMIT,
    safety_margin=SAFETY_MARGIN,
    sample_size=200,
    max_output_tokens=MAX_OUTPUT_TOKENS,
)

display(token_index)

df_fit     = token_index[token_index["fits_cap"]].reset_index(drop=True)
df_too_big = token_index[~token_index["fits_cap"]].reset_index(drop=True)

print("OK to run with Tier-1 key:")
display(df_fit[["event","split","num_rows","est_total_tokens","limit_used_%"]])

print("Too big for Tier-1 (use alternate key):")
display(df_too_big[["event","split","num_rows","est_total_tokens","limit_used_%"]])
# Out:
#                        event split  \
# 1      canada_wildfires_2016  test
# 8   kaikoura_earthquake_2016  test
# 2          cyclone_idai_2019  test
# 4    hurricane_florence_2018  test
# 7       hurricane_maria_2017  test
# 0  california_wildfires_2018  test
# 3      hurricane_dorian_2019  test
# 9         kerala_floods_2018  test
# 5      hurricane_harvey_2017  test
# 6        hurricane_irma_2017  test
#
#                                                  tsv  num_rows  \
# 1  Dataset\HumAID\canada_wildfires_2016\canada_wi...       445
# 8  Dataset\HumAID\kaikoura_earthquake_2016\kaikou...       435
# 2  Dataset\HumAID\cyclone_idai_2019\cyclone_idai_...       779
# 4  Dataset\HumAID\hurricane_florence_2018\hurrica...      1241
# 7  Dataset\HumAID\hurricane_maria_2017\hurricane_...      1442
# 0  Dataset\HumAID\california_wildfires_2018\calif...      1461
# 3  Dataset\HumAID\hurricane_dorian_2019\hurricane...      1508
# 9  Dataset\HumAID\kerala_floods_2018\kerala_flood...      1582
# 5  Dataset\HumAID\hurricane_harvey_2017\hurricane...      1805
# 6  Dataset\HumAID\hurricane_irma_2017\hurricane_i...      1862
#
#    avg_req_tokens  est_total_tokens  fits_cap  limit_used_%
# 1             473            210485      True          10.5
# 8             487            211845      True          10.6
# 2             519            404301      True          20.2
# 4             501            621741      True          31.1
# 7             487            702254      True          35.1
# 0             507            740727      True          37.0
# 3             503            758524      True          37.9
# 9             508            803656      True          40.2
# 5             486            877230      True          43.9
# 6             486            904932      True          45.2
# OK to run with Tier-1 key:
#                        event split  num_rows  est_total_tokens  limit_used_%
# 0      canada_wildfires_2016  test       445            210485          10.5
# 1   kaikoura_earthquake_2016  test       435            211845          10.6
# 2          cyclone_idai_2019  test       779            404301          20.2
# 3    hurricane_florence_2018  test      1241            621741          31.1
# 4       hurricane_maria_2017  test      1442            702254          35.1
# 5  california_wildfires_2018  test      1461            740727          37.0
# 6      hurricane_dorian_2019  test      1508            758524          37.9
# 7         kerala_floods_2018  test      1582            803656          40.2
# 8      hurricane_harvey_2017  test      1805            877230          43.9
# 9        hurricane_irma_2017  test      1862            904932          45.2
# Too big for Tier-1 (use alternate key):
# Empty DataFrame
# Columns: [event, split, num_rows, est_total_tokens, limit_used_%]
# Index: []

# %% [markdown]
# # 2) Run all datasets (sequentially)

# %%
# --- helpers to run a list of datasets ---
def run_list(dflist: pd.DataFrame, rules_text: str, model: str, tag: str):
    results = []
    for _, row in dflist.iterrows():
        event, split, tsv = row["event"], row["split"], row["tsv"]
        print(f"\n=== Running {event}/{split} ({model} | {tag}) ===")
        try:
            plan, preds, summary = run_experiment(
                dataset_path=tsv,
                rules=rules_text,
                model=model,
                tag=tag,
                dryrun_n=DRYRUN_N,
                poll_secs=POLL_SECS,
                out_root=OUT_ROOT,
                do_analysis=DO_ANALYSIS,
            )
            acc = summary.get("accuracy") if summary else float("nan")
            f1  = summary.get("macro_f1") if summary else float("nan")
            n   = summary.get("num_total_with_truth") if summary else len(preds)            
            results.append({
                "event": event,
                "split": split,
                "run_dir": str(plan["dir"]),
                "predictions_csv": str(plan["predictions_csv"]),
                "macro_f1": f1,
                "accuracy": acc,
                "num_total": n,
            })
        except Exception as e:
            print(f"[ERROR] {event}/{split}: {e}")
            results.append({
                "event": event,
                "split": split,
                "run_dir": "ERROR",
                "predictions_csv": "",
                "macro_f1": float("nan"),
                "accuracy": float("nan"),
                "num_total": 0,
            })
    return pd.DataFrame(results)

# --- 1) Use OPENAI_API_KEY_1 for smaller datasets ---
with use_api_key_env("OPENAI_API_KEY_1"):
    print(">>> Using Tier-1 key (OPENAI_API_KEY_1)")
    df_runs_small = run_list(df_fit, RULES, MODEL, tag=f"{TAG}-TIER1")
    display(df_runs_small)

# --- 2) Use OPENAI_API_KEY_2 for larger datasets ---
if not df_too_big.empty:
    with use_api_key_env("OPENAI_API_KEY_2"):
        print(">>> Using alternate key (OPENAI_API_KEY_2)")
        df_runs_big = run_list(df_too_big, RULES, MODEL, tag=f"{TAG}-ALT")
        display(df_runs_big)
else:
    df_runs_big = pd.DataFrame()
    print("No large datasets; nothing to run with the alternate key.")

# (optional) save an index of what ran under which key
from datetime import datetime
idx_dir = Path(OUT_ROOT) / "_indexes"
idx_dir.mkdir(parents=True, exist_ok=True)
stamp = datetime.now().strftime("%Y%m%d-%H%M%S")

df_runs_small.assign(key="OPENAI_API_KEY_1").to_csv(idx_dir / f"runs_tier1_{MODEL}_{TAG}_{stamp}.csv", index=False)
if not df_runs_big.empty:
    df_runs_big.assign(key="OPENAI_API_KEY_2").to_csv(idx_dir / f"runs_alt_{MODEL}_{TAG}_{stamp}.csv", index=False)
print("Saved run indexes in:", idx_dir)
# Out:
# >>> Using Tier-1 key (OPENAI_API_KEY_1)
#
# === Running canada_wildfires_2016/test (gpt-4o-mini | modeS-RULES1-filtered-TIER1) ===
# Macro-F1 (tiny sample): 0.8277777777777778
# [batch batch_6906e2b907208190b856a41ee7bb910f] status = validating
# [batch batch_6906e2b907208190b856a41ee7bb910f] status = completed
# Saved predictions to: runs\canada_wildfires_2016\test\gpt-4o-mini\20251101-214854-modeS-RULES1-filtered-TIER1\predictions.csv
# Macro-F1: 0.6522947639520669
#
# === Running kaikoura_earthquake_2016/test (gpt-4o-mini | modeS-RULES1-filtered-TIER1) ===
# Macro-F1 (tiny sample): 0.7452380952380951
# [batch batch_6906e3fccae0819080b2145ab907a2ee] status = validating
# [batch batch_6906e3fccae0819080b2145ab907a2ee] status = in_progress
# [batch batch_6906e3fccae0819080b2145ab907a2ee] status = in_progress
# [batch batch_6906e3fccae0819080b2145ab907a2ee] status = in_progress
# [batch batch_6906e3fccae0819080b2145ab907a2ee] status = completed
# Saved predictions to: runs\kaikoura_earthquake_2016\test\gpt-4o-mini\20251101-215418-modeS-RULES1-filtered-TIER1\predictions.csv
# Macro-F1: 0.7007101598364207
#
# === Running cyclone_idai_2019/test (gpt-4o-mini | modeS-RULES1-filtered-TIER1) ===
# Macro-F1 (tiny sample): 0.7571428571428571
# [batch batch_6906e8cbaad08190a0b42dddcf4611d9] status = validating
# [batch batch_6906e8cbaad08190a0b42dddcf4611d9] status = in_progress
# [batch batch_6906e8cbaad08190a0b42dddcf4611d9] status = in_progress
# [batch batch_6906e8cbaad08190a0b42dddcf4611d9] status = in_progress
# [batch batch_6906e8cbaad08190a0b42dddcf4611d9] status = completed
# Saved predictions to: runs\cyclone_idai_2019\test\gpt-4o-mini\20251101-221449-modeS-RULES1-filtered-TIER1\predictions.csv
# Macro-F1: 0.5867037317608659
#
# === Running hurricane_florence_2018/test (gpt-4o-mini | modeS-RULES1-filtered-TIER1) ===
# Macro-F1 (tiny sample): 0.7417929292929294
# [batch batch_6906ed99a3ac8190ab2a6b4f912d3e67] status = validating
# [batch batch_6906ed99a3ac8190ab2a6b4f912d3e67] status = in_progress
# [batch batch_6906ed99a3ac8190ab2a6b4f912d3e67] status = in_progress
# [batch batch_6906ed99a3ac8190ab2a6b4f912d3e67] status = in_progress
# [batch batch_6906ed99a3ac8190ab2a6b4f912d3e67] status = completed
# Saved predictions to: runs\hurricane_florence_2018\test\gpt-4o-mini\20251101-223519-modeS-RULES1-filtered-TIER1\predictions.csv
# Macro-F1: 0.6923521308119217
#
# === Running hurricane_maria_2017/test (gpt-4o-mini | modeS-RULES1-filtered-TIER1) ===
# Macro-F1 (tiny sample): 0.5427350427350427
# [batch batch_6906f2791fdc819089b6756f173ce033] status = validating
# [batch batch_6906f2791fdc819089b6756f173ce033] status = finalizing
# [batch batch_6906f2791fdc819089b6756f173ce033] status = completed
# Saved predictions to: runs\hurricane_maria_2017\test\gpt-4o-mini\20251101-225605-modeS-RULES1-filtered-TIER1\predictions.csv
# Macro-F1: 0.6285810058966068
#
# === Running california_wildfires_2018/test (gpt-4o-mini | modeS-RULES1-filtered-TIER1) ===
# Macro-F1 (tiny sample): 0.688888888888889
# [batch batch_6906f4ebe2588190a746e6a473b62383] status = validating
# [batch batch_6906f4ebe2588190a746e6a473b62383] status = in_progress
# [batch batch_6906f4ebe2588190a746e6a473b62383] status = in_progress
# [batch batch_6906f4ebe2588190a746e6a473b62383] status = in_progress
# [batch batch_6906f4ebe2588190a746e6a473b62383] status = completed
# Saved predictions to: runs\california_wildfires_2018\test\gpt-4o-mini\20251101-230632-modeS-RULES1-filtered-TIER1\predictions.csv
# Macro-F1: 0.606908943708974
#
# === Running hurricane_dorian_2019/test (gpt-4o-mini | modeS-RULES1-filtered-TIER1) ===
# Macro-F1 (tiny sample): 0.6527777777777778
# [batch batch_6906f9bcedc88190911f8ac0ca946a67] status = validating
# [batch batch_6906f9bcedc88190911f8ac0ca946a67] status = in_progress
# [batch batch_6906f9bcedc88190911f8ac0ca946a67] status = in_progress
# [batch batch_6906f9bcedc88190911f8ac0ca946a67] status = in_progress
# [batch batch_6906f9bcedc88190911f8ac0ca946a67] status = completed
# Saved predictions to: runs\hurricane_dorian_2019\test\gpt-4o-mini\20251101-232706-modeS-RULES1-filtered-TIER1\predictions.csv
# Macro-F1: 0.6004950507805684
#
# === Running kerala_floods_2018/test (gpt-4o-mini | modeS-RULES1-filtered-TIER1) ===
# Macro-F1 (tiny sample): 0.4185185185185185
# [batch batch_6906fe94238c81909916b82ac1cd6780] status = validating
# [batch batch_6906fe94238c81909916b82ac1cd6780] status = in_progress
# [batch batch_6906fe94238c81909916b82ac1cd6780] status = in_progress
# [batch batch_6906fe94238c81909916b82ac1cd6780] status = in_progress
# [batch batch_6906fe94238c81909916b82ac1cd6780] status = in_progress
# [batch batch_6906fe94238c81909916b82ac1cd6780] status = in_progress
# [batch batch_6906fe94238c81909916b82ac1cd6780] status = in_progress
# [batch batch_6906fe94238c81909916b82ac1cd6780] status = completed
# Saved predictions to: runs\kerala_floods_2018\test\gpt-4o-mini\20251101-234745-modeS-RULES1-filtered-TIER1\predictions.csv
# Macro-F1: 0.5506599032258536
#
# === Running hurricane_harvey_2017/test (gpt-4o-mini | modeS-RULES1-filtered-TIER1) ===
# Macro-F1 (tiny sample): 0.4172619047619047
# [batch batch_6907070391848190aeed5b42eeba75a5] status = validating
# [batch batch_6907070391848190aeed5b42eeba75a5] status = in_progress
# [batch batch_6907070391848190aeed5b42eeba75a5] status = in_progress
# [batch batch_6907070391848190aeed5b42eeba75a5] status = in_progress
# [batch batch_6907070391848190aeed5b42eeba75a5] status = completed
# Saved predictions to: runs\hurricane_harvey_2017\test\gpt-4o-mini\20251102-002344-modeS-RULES1-filtered-TIER1\predictions.csv
# Macro-F1: 0.6221474392418659
#
# === Running hurricane_irma_2017/test (gpt-4o-mini | modeS-RULES1-filtered-TIER1) ===
# Macro-F1 (tiny sample): 0.6523809523809524
# [batch batch_69070bd4421c8190b655c1d05612d231] status = validating
# [batch batch_69070bd4421c8190b655c1d05612d231] status = in_progress
# [batch batch_69070bd4421c8190b655c1d05612d231] status = in_progress
# [batch batch_69070bd4421c8190b655c1d05612d231] status = in_progress
# [batch batch_69070bd4421c8190b655c1d05612d231] status = in_progress
# [batch batch_69070bd4421c8190b655c1d05612d231] status = in_progress
# [batch batch_69070bd4421c8190b655c1d05612d231] status = finalizing
# [batch batch_69070bd4421c8190b655c1d05612d231] status = completed
# Saved predictions to: runs\hurricane_irma_2017\test\gpt-4o-mini\20251102-004416-modeS-RULES1-filtered-TIER1\predictions.csv
# Macro-F1: 0.6188796016308797
#                        event split  \
# 0      canada_wildfires_2016  test
# 1   kaikoura_earthquake_2016  test
# 2          cyclone_idai_2019  test
# 3    hurricane_florence_2018  test
# 4       hurricane_maria_2017  test
# 5  california_wildfires_2018  test
# 6      hurricane_dorian_2019  test
# 7         kerala_floods_2018  test
# 8      hurricane_harvey_2017  test
# 9        hurricane_irma_2017  test
#
#                                              run_dir  \
# 0  runs\canada_wildfires_2016\test\gpt-4o-mini\20...
# 1  runs\kaikoura_earthquake_2016\test\gpt-4o-mini...
# 2  runs\cyclone_idai_2019\test\gpt-4o-mini\202511...
# 3  runs\hurricane_florence_2018\test\gpt-4o-mini\...
# 4  runs\hurricane_maria_2017\test\gpt-4o-mini\202...
# 5  runs\california_wildfires_2018\test\gpt-4o-min...
# 6  runs\hurricane_dorian_2019\test\gpt-4o-mini\20...
# 7  runs\kerala_floods_2018\test\gpt-4o-mini\20251...
# 8  runs\hurricane_harvey_2017\test\gpt-4o-mini\20...
# 9  runs\hurricane_irma_2017\test\gpt-4o-mini\2025...
#
#                                      predictions_csv  macro_f1  accuracy  \
# 0  runs\canada_wildfires_2016\test\gpt-4o-mini\20...  0.652295  0.759551
# 1  runs\kaikoura_earthquake_2016\test\gpt-4o-mini...  0.700710  0.701149
# 2  runs\cyclone_idai_2019\test\gpt-4o-mini\202511...  0.586704  0.688062
# 3  runs\hurricane_florence_2018\test\gpt-4o-mini\...  0.692352  0.755842
# 4  runs\hurricane_maria_2017\test\gpt-4o-mini\202...  0.628581  0.661581
# 5  runs\california_wildfires_2018\test\gpt-4o-min...  0.606909  0.700205
# 6  runs\hurricane_dorian_2019\test\gpt-4o-mini\20...  0.600495  0.624005
# 7  runs\kerala_floods_2018\test\gpt-4o-mini\20251...  0.550660  0.673831
# 8  runs\hurricane_harvey_2017\test\gpt-4o-mini\20...  0.622147  0.662050
# 9  runs\hurricane_irma_2017\test\gpt-4o-mini\2025...  0.618880  0.642320
#
#    num_total
# 0        445
# 1        435
# 2        779
# 3       1241
# 4       1442
# 5       1461
# 6       1508
# 7       1582
# 8       1805
# 9       1862
# No large datasets; nothing to run with the alternate key.
# Saved run indexes in: runs\_indexes

# %%
from dotenv import load_dotenv; load_dotenv()
from humaidclf.batch import use_api_key_env

from humaidclf import run_experiment
from rules import RULES_1

with use_api_key_env("OPENAI_API_KEY"):
    plan, preds, summary = run_experiment(
        dataset_path="Dataset/HumAID/canada_wildfires_2016/canada_wildfires_2016_test.tsv",
        rules=RULES_1,
        model="gpt-4o-mini",
        tag="modeS-RULES1-filtered",
        dryrun_n=20,
        poll_secs=300,
        do_analysis=True,
    )
summary
# Out:
# Macro-F1 (tiny sample): 0.8277777777777778
# [batch batch_69059a818a9481909285c191da3d5ba5] status = validating
# [batch batch_69059a818a9481909285c191da3d5ba5] status = in_progress
# [batch batch_69059a818a9481909285c191da3d5ba5] status = completed
# Saved predictions to: runs\canada_wildfires_2016\test\gpt-4o-mini\20251031-222831-modeS-RULES1-filtered\predictions.csv
# Macro-F1: 0.6537930937352967
# {'num_total_with_truth': 445,
#  'num_correct': 335,
#  'num_incorrect': 110,
#  'accuracy': 0.7528089887640449,
#  'macro_f1': 0.6537930937352967,
#  'labels': ['caution_and_advice',
#   'displaced_people_and_evacuations',
#   'infrastructure_and_utility_damage',
#   'not_humanitarian',
#   'other_relevant_information',
#   'requests_or_urgent_needs',
#   'rescue_volunteering_or_donation_effort',
#   'sympathy_and_support'],
#  'labels_scope': 'truth',
#  'invalid_pred_outside_truth': 0}

# %%
from dotenv import load_dotenv; load_dotenv()
from humaidclf.batch import use_api_key_env

from humaidclf import run_experiment
from rules import RULES_1

with use_api_key_env("OPENAI_API_KEY"):
    plan, preds, summary = run_experiment(
        dataset_path="Dataset/HumAID/kaikoura_earthquake_2016/kaikoura_earthquake_2016_test.tsv",
        rules=RULES_1,
        model="gpt-4o-mini",
        tag="modeS-RULES1-filtered",
        dryrun_n=20,
        poll_secs=300,
        do_analysis=True,
    )
summary
# Out:
# Macro-F1 (tiny sample): 0.7452380952380951
# [batch batch_69067139f1188190ad38fd9e80b96d66] status = validating
# [batch batch_69067139f1188190ad38fd9e80b96d66] status = in_progress
# [batch batch_69067139f1188190ad38fd9e80b96d66] status = in_progress
# [batch batch_69067139f1188190ad38fd9e80b96d66] status = in_progress
# [batch batch_69067139f1188190ad38fd9e80b96d66] status = completed
# Saved predictions to: runs\kaikoura_earthquake_2016\test\gpt-4o-mini\20251101-134438-modeS-RULES1-filtered\predictions.csv
# Macro-F1: 0.7007742679962907
# {'num_total_with_truth': 434,
#  'num_correct': 303,
#  'num_incorrect': 131,
#  'accuracy': 0.6981566820276498,
#  'macro_f1': 0.7007742679962907,
#  'labels': ['caution_and_advice',
#   'displaced_people_and_evacuations',
#   'infrastructure_and_utility_damage',
#   'injured_or_dead_people',
#   'not_humanitarian',
#   'other_relevant_information',
#   'requests_or_urgent_needs',
#   'rescue_volunteering_or_donation_effort',
#   'sympathy_and_support'],
#  'labels_scope': 'truth',
#  'invalid_pred_outside_truth': 0}
