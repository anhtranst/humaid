# %% [markdown]
# # HumAID — Zero-shot Classification (Filtered Labels, Batch API, Sharding)
#
# - **Filtered labels (per event):** prompts + JSON schema only list labels that appear in that event’s ground truth → reduces out-of-scope (OOS) predictions.
# - **Batch API flow:** build `requests.jsonl` → upload → create batch → poll → download `outputs.jsonl` (and `errors.jsonl` if any).
# - **Patch pass:** after batch completes, any missing/blank predictions are re-classified synchronously so `predictions.csv` has one row per input.
# - **Stratified sharding (optional):** split large events into *k* shards **preserving class ratios**; use the **same** event-level labels + rules for all shards; merge predictions back in original order.
# - **Reporting:** confusion matrices (counts + row-normalized), per-class F1/error, mistakes CSV, and a sortable `results/index.html`.
#   - **Scope** = label universe used for metrics (default `truth`).
#   - **OOS preds** = predictions not in the truth set (QA signal).
#
# ## Key settings
# - `MODEL` (e.g., `gpt-4o`), `RULES` (e.g., `RULES_1`), `TAG`
# - `DRYRUN_N`, `POLL_SECS`
# - Token budgeting: `BATCH_TOKEN_LIMIT`, `SAFETY_MARGIN`, `MAX_OUTPUT_TOKENS`
# - `.env` with `OPENAI_API_KEY_1` (and optionally a second key)

# %% [markdown]
# # 0) Setup

# %%
from pathlib import Path
import math
import pandas as pd
from dotenv import load_dotenv; load_dotenv()

from humaidclf import run_experiment
from humaidclf import build_token_index               # token budgeting (sampling-based)
from humaidclf import run_experiment_sharded          # NEW: stratified sharded runner
from humaidclf.batch import use_api_key_env           # (optional) keep key switcher
from rules import RULES_2

# --- config ---
BASE = Path("Dataset/HumAID")
SPLITS = ["test"]             # or ["train","dev","test"]
MODEL = "gpt-4o"
RULES = RULES_2
TAG = "modeS-gpt-4o-RULES2-filtered"
DRYRUN_N = 20
POLL_SECS = 300
DO_ANALYSIS = True
OUT_ROOT = "runs"

# Token caps & estimates
BATCH_TOKEN_LIMIT = 90_000   # Tier-1 cap
SAFETY_MARGIN = 0.90            # use only 90% of the cap
MAX_OUTPUT_TOKENS = 40          # matches your request schema

# %% [markdown]
# # 1) Discover datasets (events/splits)

# %%
def discover_tsvs(base: Path, splits: list[str]):
    items = []
    for event_dir in sorted([p for p in base.iterdir() if p.is_dir()]):
        event = event_dir.name
        for split in splits:
            tsv = event_dir / f"{event}_{split}.tsv"
            if tsv.exists():
                items.append({"event": event, "split": split, "tsv": str(tsv)})
    return pd.DataFrame(items)

df_sources = discover_tsvs(BASE, SPLITS)

# --- token budgeting ---
token_index = build_token_index(
    df_sources,
    model=MODEL,
    rules_text=RULES,
    batch_token_limit=BATCH_TOKEN_LIMIT,
    safety_margin=SAFETY_MARGIN,
    sample_size=200,
    max_output_tokens=MAX_OUTPUT_TOKENS,
)

display(token_index)

df_fit     = token_index[token_index["fits_cap"]].reset_index(drop=True)
df_too_big = token_index[~token_index["fits_cap"]].reset_index(drop=True)

print("OK to run as single batch:")
display(df_fit[["event","split","num_rows","est_total_tokens","limit_used_%"]])

print("Will be sharded (exceeds cap):")
display(df_too_big[["event","split","num_rows","est_total_tokens","limit_used_%"]])
# Out:
#                        event split  \
# 1      canada_wildfires_2016  test
# 8   kaikoura_earthquake_2016  test
# 2          cyclone_idai_2019  test
# 4    hurricane_florence_2018  test
# 7       hurricane_maria_2017  test
# 0  california_wildfires_2018  test
# 3      hurricane_dorian_2019  test
# 9         kerala_floods_2018  test
# 5      hurricane_harvey_2017  test
# 6        hurricane_irma_2017  test
#
#                                                  tsv  num_rows  \
# 1  Dataset\HumAID\canada_wildfires_2016\canada_wi...       445
# 8  Dataset\HumAID\kaikoura_earthquake_2016\kaikou...       435
# 2  Dataset\HumAID\cyclone_idai_2019\cyclone_idai_...       779
# 4  Dataset\HumAID\hurricane_florence_2018\hurrica...      1241
# 7  Dataset\HumAID\hurricane_maria_2017\hurricane_...      1442
# 0  Dataset\HumAID\california_wildfires_2018\calif...      1461
# 3  Dataset\HumAID\hurricane_dorian_2019\hurricane...      1508
# 9  Dataset\HumAID\kerala_floods_2018\kerala_flood...      1582
# 5  Dataset\HumAID\hurricane_harvey_2017\hurricane...      1805
# 6  Dataset\HumAID\hurricane_irma_2017\hurricane_i...      1862
#
#    avg_req_tokens  est_total_tokens  fits_cap  limit_used_%
# 1             508            226060     False         251.2
# 8             522            227070     False         252.3
# 2             554            431566     False         479.5
# 4             536            665176     False         739.1
# 7             522            752724     False         836.4
# 0             542            791862     False         879.8
# 3             538            811304     False         901.4
# 9             543            859026     False         954.5
# 5             521            940405     False        1044.9
# 6             521            970102     False        1077.9
# OK to run as single batch:
# Empty DataFrame
# Columns: [event, split, num_rows, est_total_tokens, limit_used_%]
# Index: []
# Will be sharded (exceeds cap):
#                        event split  num_rows  est_total_tokens  limit_used_%
# 0      canada_wildfires_2016  test       445            226060         251.2
# 1   kaikoura_earthquake_2016  test       435            227070         252.3
# 2          cyclone_idai_2019  test       779            431566         479.5
# 3    hurricane_florence_2018  test      1241            665176         739.1
# 4       hurricane_maria_2017  test      1442            752724         836.4
# 5  california_wildfires_2018  test      1461            791862         879.8
# 6      hurricane_dorian_2019  test      1508            811304         901.4
# 7         kerala_floods_2018  test      1582            859026         954.5
# 8      hurricane_harvey_2017  test      1805            940405        1044.9
# 9        hurricane_irma_2017  test      1862            970102        1077.9

# %% [markdown]
# # 2) Run all datasets (sequentially)

# %%
def run_list_single(dflist: pd.DataFrame, rules_text: str, model: str, tag: str):
    """Run events that already fit under the cap using the normal runner."""
    results = []
    for _, row in dflist.iterrows():
        event, split, tsv = row["event"], row["split"], row["tsv"]
        print(f"\n=== Running (single) {event}/{split} ({model} | {tag}) ===")
        try:
            plan, preds, summary = run_experiment(
                dataset_path=tsv,
                rules=rules_text,
                model=model,
                tag=tag,
                dryrun_n=DRYRUN_N,
                poll_secs=POLL_SECS,
                out_root=OUT_ROOT,
                do_analysis=DO_ANALYSIS,
            )
            acc = summary.get("accuracy") if summary else float("nan")
            f1  = summary.get("macro_f1") if summary else float("nan")
            n   = summary.get("num_total_with_truth") if summary else len(preds)
            results.append({
                "event": event, "split": split,
                "run_dir": str(plan["dir"]),
                "predictions_csv": str(plan["predictions_csv"]),
                "macro_f1": f1, "accuracy": acc, "num_total": n,
                "mode": "single",
            })
        except Exception as e:
            print(f"[ERROR] {event}/{split}: {e}")
            results.append({
                "event": event, "split": split, "run_dir": "ERROR",
                "predictions_csv": "", "macro_f1": float("nan"),
                "accuracy": float("nan"), "num_total": 0, "mode": "single",
            })
    return pd.DataFrame(results)

def run_list_sharded(dflist: pd.DataFrame, token_df: pd.DataFrame, rules_text: str, model: str, tag: str):
    """Run events that exceed the cap using stratified shards. k is computed from token estimates."""
    results = []
    # Build a quick lookup: (event,split) -> est_total_tokens
    est_map = {(r.event, r.split): r.est_total_tokens for r in token_df.itertuples(index=False)}
    eff_cap = BATCH_TOKEN_LIMIT * SAFETY_MARGIN

    for _, row in dflist.iterrows():
        event, split, tsv = row["event"], row["split"], row["tsv"]
        est_tokens = est_map.get((event, split), None)
        # Conservative shard count: ceil(est / eff_cap). Min 2.
        k = max(2, math.ceil((est_tokens or (eff_cap + 1)) / eff_cap))
        print(f"\n=== Running (sharded x{k}) {event}/{split} ({model} | {tag}) ===")
        try:
            plan, preds, summary = run_experiment_sharded(
                dataset_path=tsv,
                rules=rules_text,
                model=model,
                tag=f"{tag}-sharded{k}",
                k_shards=k,
                temperature=0.0,
                poll_secs=POLL_SECS,
                out_root=OUT_ROOT,
                do_analysis=DO_ANALYSIS,
                analysis_subdir="analysis",  # merged analysis
            )
            acc = summary.get("accuracy") if summary else float("nan")
            f1  = summary.get("macro_f1") if summary else float("nan")
            n   = summary.get("num_total_with_truth") if summary else len(preds)
            results.append({
                "event": event, "split": split,
                "run_dir": str(plan["dir"]),
                "predictions_csv": str(plan["predictions_csv"]),
                "macro_f1": f1, "accuracy": acc, "num_total": n,
                "mode": f"sharded{k}",
            })
        except Exception as e:
            print(f"[ERROR] {event}/{split}: {e}")
            results.append({
                "event": event, "split": split, "run_dir": "ERROR",
                "predictions_csv": "", "macro_f1": float("nan"),
                "accuracy": float("nan"), "num_total": 0, "mode": f"sharded{k}",
            })
    return pd.DataFrame(results)

# %%
# --- Run singles with your normal key (optional context manager kept for parity)
with use_api_key_env("OPENAI_API_KEY_1"):
    print(">>> Using OPENAI_API_KEY_1")
    df_runs_single = run_list_single(df_fit, RULES, MODEL, tag=f"{TAG}-TIER1")

# --- Run sharded for the too-big ones (same key or another if you prefer)
# You can keep the same key; sharding is already controlling token usage.
with use_api_key_env("OPENAI_API_KEY_1"):
    if not df_too_big.empty:
        df_runs_sharded = run_list_sharded(df_too_big, token_index, RULES, MODEL, tag=f"{TAG}")
    else:
        df_runs_sharded = pd.DataFrame()
        print("No large datasets to shard.")

# 3) Save a small index of all runs
from datetime import datetime
idx_dir = Path(OUT_ROOT) / "_indexes"
idx_dir.mkdir(parents=True, exist_ok=True)
stamp = datetime.now().strftime("%Y%m%d-%H%M%S")

all_runs = pd.concat([df_runs_single, df_runs_sharded], ignore_index=True)
all_runs.to_csv(idx_dir / f"runs_{MODEL}_{TAG}_{stamp}.csv", index=False)
print("Saved run index at:", idx_dir)
display(all_runs)
# Out:
# >>> Using OPENAI_API_KEY_1
#
# === Running (sharded x3) canada_wildfires_2016/test (gpt-4o | modeS-gpt-4o-RULES2-filtered) ===
# [batch batch_690d84baf8688190811a944f698a73fd] status = validating
# [batch batch_690d84baf8688190811a944f698a73fd] status = failed
# [ERROR] canada_wildfires_2016/test: [shard01] batch ended with status='failed'
#
# === Running (sharded x3) kaikoura_earthquake_2016/test (gpt-4o | modeS-gpt-4o-RULES2-filtered) ===
# [batch batch_690d85ea85c881909eaf96002f1eb1cb] status = validating
# [batch batch_690d85ea85c881909eaf96002f1eb1cb] status = completed
# [batch batch_690d871908fc8190be116e8bcb1da8a7] status = validating
# [batch batch_690d871908fc8190be116e8bcb1da8a7] status = completed
# [batch batch_690d884801d481908f23635196d9312c] status = validating
# [batch batch_690d884801d481908f23635196d9312c] status = completed
# Saved merged predictions to: runs\kaikoura_earthquake_2016\test\gpt-4o\20251106-213847-modeS-gpt-4o-RULES2-filtered-sharded3\predictions.csv
# Macro-F1 (merged): 0.743671005208555
#
# === Running (sharded x6) cyclone_idai_2019/test (gpt-4o | modeS-gpt-4o-RULES2-filtered) ===
# [batch batch_690d89787f788190a346852ff1898935] status = validating
# [batch batch_690d89787f788190a346852ff1898935] status = completed
# [batch batch_690d8aa857988190bbfeaa5ab99ec063] status = validating
# [batch batch_690d8aa857988190bbfeaa5ab99ec063] status = completed
# [batch batch_690d8bd7373c8190b11108eb7eb1c483] status = validating
# [batch batch_690d8bd7373c8190b11108eb7eb1c483] status = in_progress
# [batch batch_690d8bd7373c8190b11108eb7eb1c483] status = in_progress
# [batch batch_690d8bd7373c8190b11108eb7eb1c483] status = in_progress
# [batch batch_690d8bd7373c8190b11108eb7eb1c483] status = completed
# [batch batch_690d908d00208190bae1a8fef6487453] status = validating
# [batch batch_690d908d00208190bae1a8fef6487453] status = completed
# [batch batch_690d91c01a908190aed9baea617da26c] status = validating
# [batch batch_690d91c01a908190aed9baea617da26c] status = completed
# [batch batch_690d92efa03481909d35e60cb458ad89] status = validating
# [batch batch_690d92efa03481909d35e60cb458ad89] status = completed
# Saved merged predictions to: runs\cyclone_idai_2019\test\gpt-4o\20251106-215358-modeS-gpt-4o-RULES2-filtered-sharded6\predictions.csv
# Macro-F1 (merged): 0.6228721108400883
#
# === Running (sharded x9) hurricane_florence_2018/test (gpt-4o | modeS-gpt-4o-RULES2-filtered) ===
# [batch batch_690d941f314c81909cb691dae8900ad5] status = validating
# [batch batch_690d941f314c81909cb691dae8900ad5] status = completed
# [batch batch_690d954d90a88190a77fcde171c15cc3] status = validating
# [batch batch_690d954d90a88190a77fcde171c15cc3] status = completed
# [batch batch_690d967c1104819084a1d5507dde28c1] status = validating
# [batch batch_690d967c1104819084a1d5507dde28c1] status = completed
# [batch batch_690d97aaae588190967c24f3fe4f91b3] status = validating
# [batch batch_690d97aaae588190967c24f3fe4f91b3] status = completed
# [batch batch_690d98d9ace88190b36487ea13f6bef7] status = validating
# [batch batch_690d98d9ace88190b36487ea13f6bef7] status = completed
# [batch batch_690d9a08631881908e755dc630884e3b] status = validating
# [batch batch_690d9a08631881908e755dc630884e3b] status = completed
# [batch batch_690d9b36f5fc81908cce7b53d9007e92] status = validating
# [batch batch_690d9b36f5fc81908cce7b53d9007e92] status = completed
# [batch batch_690d9c657df881908f1a4165230f9b41] status = validating
# [batch batch_690d9c657df881908f1a4165230f9b41] status = completed
# [batch batch_690d9d943c248190b9d82da0c74ea649] status = validating
# [batch batch_690d9d943c248190b9d82da0c74ea649] status = completed
# Saved merged predictions to: runs\hurricane_florence_2018\test\gpt-4o\20251106-223925-modeS-gpt-4o-RULES2-filtered-sharded9\predictions.csv
# Macro-F1 (merged): 0.6813464342860577
#
# === Running (sharded x10) hurricane_maria_2017/test (gpt-4o | modeS-gpt-4o-RULES2-filtered) ===
# [batch batch_690d9ec3c3148190a83bb288bc6c7889] status = validating
# [batch batch_690d9ec3c3148190a83bb288bc6c7889] status = completed
# [batch batch_690d9ff38f4881909c4012cff8426f9b] status = validating
# [batch batch_690d9ff38f4881909c4012cff8426f9b] status = completed
# [batch batch_690da122bac481909be72cf23620e1fb] status = validating
# [batch batch_690da122bac481909be72cf23620e1fb] status = in_progress
# [batch batch_690da122bac481909be72cf23620e1fb] status = in_progress
# [batch batch_690da122bac481909be72cf23620e1fb] status = in_progress
# [batch batch_690da122bac481909be72cf23620e1fb] status = completed
# [batch batch_690da5d8b9fc81909ce3cab910acbb93] status = validating
# [batch batch_690da5d8b9fc81909ce3cab910acbb93] status = in_progress
# [batch batch_690da5d8b9fc81909ce3cab910acbb93] status = in_progress
# [batch batch_690da5d8b9fc81909ce3cab910acbb93] status = in_progress
# [batch batch_690da5d8b9fc81909ce3cab910acbb93] status = completed
# [batch batch_690daa9115948190870f5de66cc68f67] status = validating
# [batch batch_690daa9115948190870f5de66cc68f67] status = completed
# [batch batch_690dabc01dfc819098d726000996ae50] status = validating
# [batch batch_690dabc01dfc819098d726000996ae50] status = completed
# [batch batch_690dacee8fd08190bbc6fbc8cffc3c9c] status = validating
# [batch batch_690dacee8fd08190bbc6fbc8cffc3c9c] status = completed
# [batch batch_690dae1d32fc8190b381d219f951f45b] status = validating
# [batch batch_690dae1d32fc8190b381d219f951f45b] status = completed
# [batch batch_690daf4b91f48190968dab570f9cf6d1] status = validating
# [batch batch_690daf4b91f48190968dab570f9cf6d1] status = completed
# [batch batch_690db07a63448190921a679f7668c9fe] status = validating
# [batch batch_690db07a63448190921a679f7668c9fe] status = in_progress
# [batch batch_690db07a63448190921a679f7668c9fe] status = in_progress
# [batch batch_690db07a63448190921a679f7668c9fe] status = in_progress
# [batch batch_690db07a63448190921a679f7668c9fe] status = completed
# Saved merged predictions to: runs\hurricane_maria_2017\test\gpt-4o\20251106-232450-modeS-gpt-4o-RULES2-filtered-sharded10\predictions.csv
# Macro-F1 (merged): 0.6253986964787887
#
# === Running (sharded x10) california_wildfires_2018/test (gpt-4o | modeS-gpt-4o-RULES2-filtered) ===
# [batch batch_690db534e3348190917cb1bc61324ab9] status = validating
# [batch batch_690db534e3348190917cb1bc61324ab9] status = completed
# [batch batch_690db663fdac81909efd791fddb52d69] status = validating
# [batch batch_690db663fdac81909efd791fddb52d69] status = completed
# [batch batch_690db792920881909451008fea97126b] status = validating
# [batch batch_690db792920881909451008fea97126b] status = completed
# [batch batch_690db8c168088190a2ad4519ff1991c7] status = validating
# [batch batch_690db8c168088190a2ad4519ff1991c7] status = in_progress
# [batch batch_690db8c168088190a2ad4519ff1991c7] status = in_progress
# [batch batch_690db8c168088190a2ad4519ff1991c7] status = in_progress
# [batch batch_690db8c168088190a2ad4519ff1991c7] status = completed
# [batch batch_690dbd7865e08190b873fdb066491a9f] status = validating
# [batch batch_690dbd7865e08190b873fdb066491a9f] status = in_progress
# [batch batch_690dbd7865e08190b873fdb066491a9f] status = in_progress
# [batch batch_690dbd7865e08190b873fdb066491a9f] status = in_progress
# [batch batch_690dbd7865e08190b873fdb066491a9f] status = completed
# [batch batch_690dc22d71e08190b57c923c00654fa8] status = validating
# [batch batch_690dc22d71e08190b57c923c00654fa8] status = completed
# [batch batch_690dc35c010c8190b3d13ff1415ab5c6] status = validating
# [batch batch_690dc35c010c8190b3d13ff1415ab5c6] status = completed
# [batch batch_690dc48af4d881908b979bc015e3ae97] status = validating
# [batch batch_690dc48af4d881908b979bc015e3ae97] status = completed
# [batch batch_690dc5b9d2e08190a2868cc72270d23c] status = validating
# [batch batch_690dc5b9d2e08190a2868cc72270d23c] status = completed
# [batch batch_690dc6e871548190bf8b22b6d062149e] status = validating
# [batch batch_690dc6e871548190bf8b22b6d062149e] status = completed
# Saved merged predictions to: runs\california_wildfires_2018\test\gpt-4o\20251107-010034-modeS-gpt-4o-RULES2-filtered-sharded10\predictions.csv
# Macro-F1 (merged): 0.6095066468096397
#
# === Running (sharded x11) hurricane_dorian_2019/test (gpt-4o | modeS-gpt-4o-RULES2-filtered) ===
# [batch batch_690dc818181c819093359bf3b30b13e5] status = validating
# [batch batch_690dc818181c819093359bf3b30b13e5] status = completed
# [batch batch_690dc946c5508190b3df6567a1455829] status = validating
# [batch batch_690dc946c5508190b3df6567a1455829] status = completed
# [batch batch_690dca75e24c8190be54929a503f64b7] status = validating
# [batch batch_690dca75e24c8190be54929a503f64b7] status = completed
# [batch batch_690dcba615ec8190818df46bb8af68f7] status = validating
# [batch batch_690dcba615ec8190818df46bb8af68f7] status = completed
# [batch batch_690dccd4b0c081908d315319953bd985] status = validating
# [batch batch_690dccd4b0c081908d315319953bd985] status = completed
# [batch batch_690dce035870819088e497c1b199624c] status = validating
# [batch batch_690dce035870819088e497c1b199624c] status = completed
# [batch batch_690dcf31ea0c81909710cd26f6d4aa00] status = validating
# [batch batch_690dcf31ea0c81909710cd26f6d4aa00] status = completed
# [batch batch_690dd061ac348190b298ffe18ed0f781] status = validating
# [batch batch_690dd061ac348190b298ffe18ed0f781] status = completed
# [batch batch_690dd1906f388190aa0e7d5049fd8222] status = validating
# [batch batch_690dd1906f388190aa0e7d5049fd8222] status = completed
# [batch batch_690dd2befcc081908339d55a05a581c3] status = validating
# [batch batch_690dd2befcc081908339d55a05a581c3] status = completed
# [batch batch_690dd3eda1988190b414136faf17ae38] status = validating
# [batch batch_690dd3eda1988190b414136faf17ae38] status = completed
# Saved merged predictions to: runs\hurricane_dorian_2019\test\gpt-4o\20251107-022110-modeS-gpt-4o-RULES2-filtered-sharded11\predictions.csv
# Macro-F1 (merged): 0.5974231517843572
#
# === Running (sharded x11) kerala_floods_2018/test (gpt-4o | modeS-gpt-4o-RULES2-filtered) ===
# [batch batch_690dd524ca2c81909de089a1981b0105] status = validating
# [batch batch_690dd524ca2c81909de089a1981b0105] status = completed
# [batch batch_690dd654a4c881909e3f7b7dd2a02bce] status = validating
# [batch batch_690dd654a4c881909e3f7b7dd2a02bce] status = completed
# [batch batch_690dd783c1b081909540b29ec53717b5] status = validating
# [batch batch_690dd783c1b081909540b29ec53717b5] status = completed
# [batch batch_690dd8b2253c819084de94673a98af3f] status = validating
# [batch batch_690dd8b2253c819084de94673a98af3f] status = completed
# [batch batch_690dd9e1beb881909a3296cbf35c29b6] status = validating
# [batch batch_690dd9e1beb881909a3296cbf35c29b6] status = in_progress
# [batch batch_690dd9e1beb881909a3296cbf35c29b6] status = in_progress
# [batch batch_690dd9e1beb881909a3296cbf35c29b6] status = in_progress
# [batch batch_690dd9e1beb881909a3296cbf35c29b6] status = in_progress
# [batch batch_690dd9e1beb881909a3296cbf35c29b6] status = in_progress
# [batch batch_690dd9e1beb881909a3296cbf35c29b6] status = in_progress
# [batch batch_690dd9e1beb881909a3296cbf35c29b6] status = in_progress
# [batch batch_690dd9e1beb881909a3296cbf35c29b6] status = completed
# [batch batch_690de34923608190b6c8d66ea779847a] status = validating
# [batch batch_690de34923608190b6c8d66ea779847a] status = completed
# [batch batch_690de477ac44819099daf82135cb2df5] status = validating
# [batch batch_690de477ac44819099daf82135cb2df5] status = completed
# [batch batch_690de5a5d0f081909846918061a447aa] status = validating
# [batch batch_690de5a5d0f081909846918061a447aa] status = completed
# [batch batch_690de6d4dcd081909d1f80ecb04ee6f9] status = validating
# [batch batch_690de6d4dcd081909d1f80ecb04ee6f9] status = completed
# [batch batch_690de8039e30819094210625736e3b37] status = validating
# [batch batch_690de8039e30819094210625736e3b37] status = completed
# [batch batch_690de93296e8819091ebb595e58d3244] status = validating
# [batch batch_690de93296e8819091ebb595e58d3244] status = completed
# Saved merged predictions to: runs\kerala_floods_2018\test\gpt-4o\20251107-031649-modeS-gpt-4o-RULES2-filtered-sharded11\predictions.csv
# Macro-F1 (merged): 0.5694106394248029
#
# === Running (sharded x12) hurricane_harvey_2017/test (gpt-4o | modeS-gpt-4o-RULES2-filtered) ===
# [batch batch_690dea62b1fc8190865c45bc28e20fdb] status = validating
# [batch batch_690dea62b1fc8190865c45bc28e20fdb] status = completed
# [batch batch_690deb92a9ac81909a0ec012eaddfed9] status = validating
# [batch batch_690deb92a9ac81909a0ec012eaddfed9] status = completed
# [batch batch_690decc155c881909334dc7997bec65c] status = validating
# [batch batch_690decc155c881909334dc7997bec65c] status = completed
# [batch batch_690dedef98ec819098b732c3ce9804f5] status = validating
# [batch batch_690dedef98ec819098b732c3ce9804f5] status = completed
# [batch batch_690def1eb8c48190afacd3a69c139188] status = validating
# [batch batch_690def1eb8c48190afacd3a69c139188] status = completed
# [batch batch_690df04d9d8c81908cd361486734c356] status = validating
# [batch batch_690df04d9d8c81908cd361486734c356] status = in_progress
# [batch batch_690df04d9d8c81908cd361486734c356] status = in_progress
# [batch batch_690df04d9d8c81908cd361486734c356] status = in_progress
# [batch batch_690df04d9d8c81908cd361486734c356] status = completed
# [batch batch_690df50a3320819087c3136eed0f4dab] status = validating
# [batch batch_690df50a3320819087c3136eed0f4dab] status = completed
# [batch batch_690df638db7081908794bb3ce4fbec24] status = validating
# [batch batch_690df638db7081908794bb3ce4fbec24] status = in_progress
# [batch batch_690df638db7081908794bb3ce4fbec24] status = in_progress
# [batch batch_690df638db7081908794bb3ce4fbec24] status = in_progress
# [batch batch_690df638db7081908794bb3ce4fbec24] status = completed
# [batch batch_690dfaf072f08190bda81a05de7d87c5] status = validating
# [batch batch_690dfaf072f08190bda81a05de7d87c5] status = completed
# [batch batch_690dfc1f1820819096db755bc7b149c8] status = validating
# [batch batch_690dfc1f1820819096db755bc7b149c8] status = completed
# [batch batch_690dfd4df5b881909dd71b79c4dc12cd] status = validating
# [batch batch_690dfd4df5b881909dd71b79c4dc12cd] status = completed
# [batch batch_690dfe7cbb688190a475d65f8223388e] status = validating
# [batch batch_690dfe7cbb688190a475d65f8223388e] status = in_progress
# [batch batch_690dfe7cbb688190a475d65f8223388e] status = in_progress
# [batch batch_690dfe7cbb688190a475d65f8223388e] status = in_progress
# [batch batch_690dfe7cbb688190a475d65f8223388e] status = completed
# Saved merged predictions to: runs\hurricane_harvey_2017\test\gpt-4o\20251107-044727-modeS-gpt-4o-RULES2-filtered-sharded12\predictions.csv
# Macro-F1 (merged): 0.6136874270888965
#
# === Running (sharded x12) hurricane_irma_2017/test (gpt-4o | modeS-gpt-4o-RULES2-filtered) ===
# [batch batch_690e0337e58c819096f46b480003b101] status = validating
# [batch batch_690e0337e58c819096f46b480003b101] status = completed
# [batch batch_690e046691188190929a5019d9bd6cdd] status = validating
# [batch batch_690e046691188190929a5019d9bd6cdd] status = completed
# [batch batch_690e0595ef688190b97b223aa4ca4b63] status = validating
# [batch batch_690e0595ef688190b97b223aa4ca4b63] status = completed
# [batch batch_690e06c5bde88190a5fde5c35eb3c3bf] status = validating
# [batch batch_690e06c5bde88190a5fde5c35eb3c3bf] status = completed
# [batch batch_690e07f454848190acde630076e7d792] status = validating
# [batch batch_690e07f454848190acde630076e7d792] status = completed
# [batch batch_690e0922dc4c8190a49668e705a18a13] status = validating
# [batch batch_690e0922dc4c8190a49668e705a18a13] status = completed
# [batch batch_690e0a5710988190b28cd95837f0de8b] status = validating
# [batch batch_690e0a5710988190b28cd95837f0de8b] status = in_progress
# [batch batch_690e0a5710988190b28cd95837f0de8b] status = in_progress
# [batch batch_690e0a5710988190b28cd95837f0de8b] status = in_progress
# [batch batch_690e0a5710988190b28cd95837f0de8b] status = completed
# [batch batch_690e0f0ec3788190a5445bb5da1cb37a] status = validating
# [batch batch_690e0f0ec3788190a5445bb5da1cb37a] status = in_progress
# [batch batch_690e0f0ec3788190a5445bb5da1cb37a] status = in_progress
# [batch batch_690e0f0ec3788190a5445bb5da1cb37a] status = in_progress
# [batch batch_690e0f0ec3788190a5445bb5da1cb37a] status = completed
# [batch batch_690e13c6e0a081909c567b0f92aff687] status = validating
# [batch batch_690e13c6e0a081909c567b0f92aff687] status = completed
# [batch batch_690e14f5be8c81908a246c9d9f9de48d] status = validating
# [batch batch_690e14f5be8c81908a246c9d9f9de48d] status = completed
# [batch batch_690e162434bc8190973c9804eb17f70e] status = validating
# [batch batch_690e162434bc8190973c9804eb17f70e] status = completed
# [batch batch_690e1753152881909c1548778560958f] status = validating
# [batch batch_690e1753152881909c1548778560958f] status = completed
# Saved merged predictions to: runs\hurricane_irma_2017\test\gpt-4o\20251107-063325-modeS-gpt-4o-RULES2-filtered-sharded12\predictions.csv
# Macro-F1 (merged): 0.614657161694911
# Saved run index at: runs\_indexes
#                        event split  \
# 0      canada_wildfires_2016  test
# 1   kaikoura_earthquake_2016  test
# 2          cyclone_idai_2019  test
# 3    hurricane_florence_2018  test
# 4       hurricane_maria_2017  test
# 5  california_wildfires_2018  test
# 6      hurricane_dorian_2019  test
# 7         kerala_floods_2018  test
# 8      hurricane_harvey_2017  test
# 9        hurricane_irma_2017  test
#
#                                              run_dir  \
# 0                                              ERROR
# 1  runs\kaikoura_earthquake_2016\test\gpt-4o\2025...
# 2  runs\cyclone_idai_2019\test\gpt-4o\20251106-21...
# 3  runs\hurricane_florence_2018\test\gpt-4o\20251...
# 4  runs\hurricane_maria_2017\test\gpt-4o\20251106...
# 5  runs\california_wildfires_2018\test\gpt-4o\202...
# 6  runs\hurricane_dorian_2019\test\gpt-4o\2025110...
# 7  runs\kerala_floods_2018\test\gpt-4o\20251107-0...
# 8  runs\hurricane_harvey_2017\test\gpt-4o\2025110...
# 9  runs\hurricane_irma_2017\test\gpt-4o\20251107-...
#
#                                      predictions_csv  macro_f1  accuracy  \
# 0                                                          NaN       NaN
# 1  runs\kaikoura_earthquake_2016\test\gpt-4o\2025...  0.743671  0.737931
# 2  runs\cyclone_idai_2019\test\gpt-4o\20251106-21...  0.622872  0.729140
# 3  runs\hurricane_florence_2018\test\gpt-4o\20251...  0.681346  0.752619
# 4  runs\hurricane_maria_2017\test\gpt-4o\20251106...  0.625399  0.653953
# 5  runs\california_wildfires_2018\test\gpt-4o\202...  0.609507  0.697467
# 6  runs\hurricane_dorian_2019\test\gpt-4o\2025110...  0.597423  0.635279
# 7  runs\kerala_floods_2018\test\gpt-4o\20251107-0...  0.569411  0.697851
# 8  runs\hurricane_harvey_2017\test\gpt-4o\2025110...  0.613687  0.655402
# 9  runs\hurricane_irma_2017\test\gpt-4o\20251107-...  0.614657  0.622986
#
#    num_total       mode
# 0          0   sharded3
# 1        435   sharded3
# 2        779   sharded6
# 3       1241   sharded9
# 4       1442  sharded10
# 5       1461  sharded10
# 6       1508  sharded11
# 7       1582  sharded11
# 8       1805  sharded12
# 9       1862  sharded12

# %% [markdown]
# # Other experiments

# %%
from pathlib import Path
import math
import pandas as pd
from dotenv import load_dotenv; load_dotenv()

from humaidclf import run_experiment
from humaidclf import build_token_index               # token budgeting (sampling-based)
from humaidclf import run_experiment_sharded          # NEW: stratified sharded runner
from humaidclf.batch import use_api_key_env           # (optional) keep key switcher
from rules import RULES_1

# --- config ---
BASE = Path("Dataset/HumAID")
SPLITS = ["test"]             # or ["train","dev","test"]
MODEL = "gpt-4-0613"
RULES = RULES_1
TAG = "modeS-gpt-41-RULES1-filtered"
DRYRUN_N = 20
POLL_SECS = 300
DO_ANALYSIS = True
OUT_ROOT = "runs"

K = 10  # number of stratified shards

with use_api_key_env("OPENAI_API_KEY"):
    plan, preds, summary = run_experiment_sharded(
        dataset_path=str(BASE / "canada_wildfires_2016" / "canada_wildfires_2016_test.tsv"),
        rules=RULES,
        model=MODEL,
        tag=f"{TAG}-sharded{K}",
        k_shards=K,
        temperature=0.0,
        poll_secs=POLL_SECS,
        out_root=OUT_ROOT,
        do_analysis=DO_ANALYSIS,
        analysis_subdir="analysis",
    )

summary
