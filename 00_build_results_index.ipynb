# %%
import importlib
import humaidclf.report as report  # import the module, not the function

# make sure we're using the updated file on disk
importlib.reload(report)

report.build_results_index(
    "results",
    out_html="results/index.html",
    recompute=True,
    recompute_missing_only=True,
)
# Out:
#                         event  split        model  \
# 0   california_wildfires_2018   test      gpt-4.1
# 1   california_wildfires_2018   test       gpt-4o
# 2   california_wildfires_2018   test       gpt-4o
# 3   california_wildfires_2018   test       gpt-4o
# 4   california_wildfires_2018   test  gpt-4o-mini
# ..                        ...    ...          ...
# 60      hurricane_harvey_2017  train  gpt-4o-mini
# 61        hurricane_irma_2017  train  gpt-4o-mini
# 62       hurricane_maria_2017  train  gpt-4o-mini
# 63   kaikoura_earthquake_2016  train  gpt-4o-mini
# 64         kerala_floods_2018  train  gpt-4o-mini
#
#                                              run_name  \
# 0   20251105-000600-modeS-gpt-41-RULES1-filtered-s...
# 1   20251104-042558-modeS-gpt-4o-RULES1-filtered-s...
# 2   20251106-194112-modeS-gpt-4o-RULES2-filtered-s...
# 3   20251107-010034-modeS-gpt-4o-RULES2-filtered-s...
# 4         20251101-230632-modeS-RULES1-filtered-TIER1
# ..                                                ...
# 60                   20251022-001305-modeS-RULES1-ALT
# 61                   20251022-004334-modeS-RULES1-ALT
# 62                   20251021-215113-modeS-RULES1-ALT
# 63                 20251021-182421-modeS-RULES1-TIER1
# 64                   20251021-231731-modeS-RULES1-ALT
#
#                                                   dir  \
# 0   results\california_wildfires_2018\test\gpt-4.1...
# 1   results\california_wildfires_2018\test\gpt-4o\...
# 2   results\california_wildfires_2018\test\gpt-4o\...
# 3   results\california_wildfires_2018\test\gpt-4o\...
# 4   results\california_wildfires_2018\test\gpt-4o-...
# ..                                                ...
# 60  results\hurricane_harvey_2017\train\gpt-4o-min...
# 61  results\hurricane_irma_2017\train\gpt-4o-mini\...
# 62  results\hurricane_maria_2017\train\gpt-4o-mini...
# 63  results\kaikoura_earthquake_2016\train\gpt-4o-...
# 64  results\kerala_floods_2018\train\gpt-4o-mini\2...
#
#                                       predictions_csv  test_size  accuracy  \
# 0   results\california_wildfires_2018\test\gpt-4.1...       1461  0.710472
# 1   results\california_wildfires_2018\test\gpt-4o\...       1461  0.712526
# 2   results\california_wildfires_2018\test\gpt-4o\...       1461  0.696099
# 3   results\california_wildfires_2018\test\gpt-4o\...       1461  0.697467
# 4   results\california_wildfires_2018\test\gpt-4o-...       1461  0.700205
# ..                                                ...        ...       ...
# 60  results\hurricane_harvey_2017\train\gpt-4o-min...       6378  0.668184
# 61  results\hurricane_irma_2017\train\gpt-4o-mini\...       6579  0.638648
# 62  results\hurricane_maria_2017\train\gpt-4o-mini...       5094  0.665419
# 63  results\kaikoura_earthquake_2016\train\gpt-4o-...       1536  0.694661
# 64  results\kerala_floods_2018\train\gpt-4o-mini\2...       5588  0.681411
#
#     macro_f1                                         charts_dir labels_scope  \
# 0   0.635326  results\california_wildfires_2018\test\gpt-4.1...        truth
# 1   0.628638  results\california_wildfires_2018\test\gpt-4o\...        truth
# 2   0.614285  results\california_wildfires_2018\test\gpt-4o\...        truth
# 3   0.609507  results\california_wildfires_2018\test\gpt-4o\...        truth
# 4   0.606909  results\california_wildfires_2018\test\gpt-4o-...        truth
# ..       ...                                                ...          ...
# 60  0.629773  results\hurricane_harvey_2017\train\gpt-4o-min...        truth
# 61  0.617021  results\hurricane_irma_2017\train\gpt-4o-mini\...        truth
# 62  0.641164  results\hurricane_maria_2017\train\gpt-4o-mini...        truth
# 63  0.666262  results\kaikoura_earthquake_2016\train\gpt-4o-...        truth
# 64  0.566125  results\kerala_floods_2018\train\gpt-4o-mini\2...        truth
#
#     invalid_pred_outside_truth                    oos_breakdown
# 0                            0                               []
# 1                            0                               []
# 2                            0                               []
# 3                            0                               []
# 4                            0                               []
# ..                         ...                              ...
# 60                           7   [(missing_or_found_people, 7)]
# 61                          12  [(missing_or_found_people, 12)]
# 62                          16  [(missing_or_found_people, 16)]
# 63                           0                               []
# 64                           4   [(missing_or_found_people, 4)]
#
# [65 rows x 13 columns]

# %%
from IPython.display import IFrame

# height can be whatever you like
IFrame(src="results/index.html", width="100%", height=900)
# Out:
#         <iframe
#             width="100%"
#             height="900"
#             src="results/index.html"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
