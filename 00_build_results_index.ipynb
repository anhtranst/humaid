# %%
from humaidclf.report import build_results_index

# Build/refresh summary page from curated results/
df = build_results_index("results", out_html="results/index.html")
df  # table of (event, split, model, run_name, test_size, accuracy, macro_f1)
# Out:
#                        event  split        model  \
# 0  california_wildfires_2018  train  gpt-4o-mini
# 1      canada_wildfires_2016  train  gpt-4o-mini
# 2          cyclone_idai_2019  train  gpt-4o-mini
# 3      hurricane_dorian_2019  train  gpt-4o-mini
# 4    hurricane_florence_2018  train  gpt-4o-mini
# 5      hurricane_harvey_2017  train  gpt-4o-mini
# 6        hurricane_irma_2017  train  gpt-4o-mini
# 7       hurricane_maria_2017  train  gpt-4o-mini
# 8   kaikoura_earthquake_2016  train  gpt-4o-mini
# 9         kerala_floods_2018  train  gpt-4o-mini
#
#                              run_name  \
# 0    20251021-222139-modeS-RULES1-ALT
# 1  20251021-202956-modeS-RULES1-TIER1
# 2  20251021-205521-modeS-RULES1-TIER1
# 3    20251021-224703-modeS-RULES1-ALT
# 4    20251021-212048-modeS-RULES1-ALT
# 5    20251022-001305-modeS-RULES1-ALT
# 6    20251022-004334-modeS-RULES1-ALT
# 7    20251021-215113-modeS-RULES1-ALT
# 8  20251021-182421-modeS-RULES1-TIER1
# 9    20251021-231731-modeS-RULES1-ALT
#
#                                                  dir  test_size  accuracy  \
# 0  results\california_wildfires_2018\train\gpt-4o...       5163  0.705791
# 1  results\canada_wildfires_2016\train\gpt-4o-min...       1569  0.773104
# 2  results\cyclone_idai_2019\train\gpt-4o-mini\20...       2753  0.683255
# 3  results\hurricane_dorian_2019\train\gpt-4o-min...       5329  0.617940
# 4  results\hurricane_florence_2018\train\gpt-4o-m...       4384  0.736770
# 5  results\hurricane_harvey_2017\train\gpt-4o-min...       6378  0.667451
# 6  results\hurricane_irma_2017\train\gpt-4o-mini\...       6579  0.637483
# 7  results\hurricane_maria_2017\train\gpt-4o-mini...       5094  0.663329
# 8  results\kaikoura_earthquake_2016\train\gpt-4o-...       1536  0.694661
# 9  results\kerala_floods_2018\train\gpt-4o-mini\2...       5588  0.680923
#
#    macro_f1                                         charts_dir
# 0  0.615469  results\california_wildfires_2018\train\gpt-4o...
# 1  0.586217  results\canada_wildfires_2016\train\gpt-4o-min...
# 2  0.578483  results\cyclone_idai_2019\train\gpt-4o-mini\20...
# 3  0.584102  results\hurricane_dorian_2019\train\gpt-4o-min...
# 4  0.600411  results\hurricane_florence_2018\train\gpt-4o-m...
# 5  0.566796  results\hurricane_harvey_2017\train\gpt-4o-min...
# 6  0.555319  results\hurricane_irma_2017\train\gpt-4o-mini\...
# 7  0.577048  results\hurricane_maria_2017\train\gpt-4o-mini...
# 8  0.666262  results\kaikoura_earthquake_2016\train\gpt-4o-...
# 9  0.509513  results\kerala_floods_2018\train\gpt-4o-mini\2...

# %%
from IPython.display import IFrame

# height can be whatever you like
IFrame(src="results/index.html", width="100%", height=900)
# Out:
#         <iframe
#             width="100%"
#             height="900"
#             src="results/index.html"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
