# %%
from humaidclf.report import build_results_index

# Build/refresh summary page from curated results/
df = build_results_index("results", out_html="results/index.html")
df  # table of (event, split, model, run_name, test_size, accuracy, macro_f1)
# Out:
#                         event  split        model  \
# 0   california_wildfires_2018   test  gpt-4o-mini
# 1       canada_wildfires_2016   test  gpt-4o-mini
# 2           cyclone_idai_2019   test  gpt-4o-mini
# 3       hurricane_dorian_2019   test  gpt-4o-mini
# 4     hurricane_florence_2018   test  gpt-4o-mini
# 5       hurricane_harvey_2017   test  gpt-4o-mini
# 6         hurricane_irma_2017   test  gpt-4o-mini
# 7        hurricane_maria_2017   test  gpt-4o-mini
# 8    kaikoura_earthquake_2016   test  gpt-4o-mini
# 9          kerala_floods_2018   test  gpt-4o-mini
# 10  california_wildfires_2018  train  gpt-4o-mini
# 11      canada_wildfires_2016  train  gpt-4o-mini
# 12          cyclone_idai_2019  train  gpt-4o-mini
# 13      hurricane_dorian_2019  train  gpt-4o-mini
# 14    hurricane_florence_2018  train  gpt-4o-mini
# 15      hurricane_harvey_2017  train  gpt-4o-mini
# 16        hurricane_irma_2017  train  gpt-4o-mini
# 17       hurricane_maria_2017  train  gpt-4o-mini
# ...

# %%
from IPython.display import IFrame

# height can be whatever you like
IFrame(src="results/index.html", width="100%", height=900)
# Out:
#         <iframe
#             width="100%"
#             height="900"
#             src="results/index.html"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
