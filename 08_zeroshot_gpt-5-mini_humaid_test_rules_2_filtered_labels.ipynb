# %% [markdown]
# # HumAID — Zero-shot Classification (Filtered Labels, Batch API, Sharding)
#
# - **Filtered labels (per event):** prompts + JSON schema only list labels that appear in that event’s ground truth → reduces out-of-scope (OOS) predictions.
# - **Batch API flow:** build `requests.jsonl` → upload → create batch → poll → download `outputs.jsonl` (and `errors.jsonl` if any).
# - **Patch pass:** after batch completes, any missing/blank predictions are re-classified synchronously so `predictions.csv` has one row per input.
# - **Stratified sharding (optional):** split large events into *k* shards **preserving class ratios**; use the **same** event-level labels + rules for all shards; merge predictions back in original order.
# - **Reporting:** confusion matrices (counts + row-normalized), per-class F1/error, mistakes CSV, and a sortable `results/index.html`.
#   - **Scope** = label universe used for metrics (default `truth`).
#   - **OOS preds** = predictions not in the truth set (QA signal).
#
# ## Key settings
# - `MODEL` (e.g., `gpt-4o`), `RULES` (e.g., `RULES_1`), `TAG`
# - `DRYRUN_N`, `POLL_SECS`
# - Token budgeting: `BATCH_TOKEN_LIMIT`, `SAFETY_MARGIN`, `MAX_OUTPUT_TOKENS`
# - `.env` with `OPENAI_API_KEY_1` (and optionally a second key)

# %% [markdown]
# # 0) Setup

# %%
from pathlib import Path
import math
import pandas as pd
from dotenv import load_dotenv; load_dotenv()

from humaidclf import run_experiment
from humaidclf import build_token_index               # token budgeting (sampling-based)
from humaidclf import run_experiment_sharded          # NEW: stratified sharded runner
from humaidclf.batch import use_api_key_env           # (optional) keep key switcher
from rules import RULES_2

# --- config ---
BASE = Path("Dataset/HumAID")
SPLITS = ["test"]             # or ["train","dev","test"]
MODEL = "gpt-5-mini"
RULES = RULES_2
TAG = "modeS-gpt-5-mini-RULES2-filtered"
DRYRUN_N = 20
POLL_SECS = 300
DO_ANALYSIS = True
OUT_ROOT = "runs"

# Token caps & estimates
BATCH_TOKEN_LIMIT = 90_000   # Tier-1 cap
SAFETY_MARGIN = 0.90            # use only 90% of the cap
MAX_OUTPUT_TOKENS = 40          # matches your request schema

# %% [markdown]
# # 1) Discover datasets (events/splits)

# %%
def discover_tsvs(base: Path, splits: list[str]):
    items = []
    for event_dir in sorted([p for p in base.iterdir() if p.is_dir()]):
        event = event_dir.name
        for split in splits:
            tsv = event_dir / f"{event}_{split}.tsv"
            if tsv.exists():
                items.append({"event": event, "split": split, "tsv": str(tsv)})
    return pd.DataFrame(items)

df_sources = discover_tsvs(BASE, SPLITS)

# --- token budgeting ---
token_index = build_token_index(
    df_sources,
    model=MODEL,
    rules_text=RULES,
    batch_token_limit=BATCH_TOKEN_LIMIT,
    safety_margin=SAFETY_MARGIN,
    sample_size=200,
    max_output_tokens=MAX_OUTPUT_TOKENS,
)

display(token_index)

df_fit     = token_index[token_index["fits_cap"]].reset_index(drop=True)
df_too_big = token_index[~token_index["fits_cap"]].reset_index(drop=True)

print("OK to run as single batch:")
display(df_fit[["event","split","num_rows","est_total_tokens","limit_used_%"]])

print("Will be sharded (exceeds cap):")
display(df_too_big[["event","split","num_rows","est_total_tokens","limit_used_%"]])
# Out:
#                        event split  \
# 1      canada_wildfires_2016  test
# 8   kaikoura_earthquake_2016  test
# 2          cyclone_idai_2019  test
# 4    hurricane_florence_2018  test
# 7       hurricane_maria_2017  test
# 0  california_wildfires_2018  test
# 3      hurricane_dorian_2019  test
# 9         kerala_floods_2018  test
# 5      hurricane_harvey_2017  test
# 6        hurricane_irma_2017  test
#
#                                                  tsv  num_rows  \
# 1  Dataset\HumAID\canada_wildfires_2016\canada_wi...       445
# 8  Dataset\HumAID\kaikoura_earthquake_2016\kaikou...       435
# 2  Dataset\HumAID\cyclone_idai_2019\cyclone_idai_...       779
# 4  Dataset\HumAID\hurricane_florence_2018\hurrica...      1241
# 7  Dataset\HumAID\hurricane_maria_2017\hurricane_...      1442
# 0  Dataset\HumAID\california_wildfires_2018\calif...      1461
# 3  Dataset\HumAID\hurricane_dorian_2019\hurricane...      1508
# 9  Dataset\HumAID\kerala_floods_2018\kerala_flood...      1582
# 5  Dataset\HumAID\hurricane_harvey_2017\hurricane...      1805
# 6  Dataset\HumAID\hurricane_irma_2017\hurricane_i...      1862
#
#    avg_req_tokens  est_total_tokens  fits_cap  limit_used_%
# 1             508            226060     False         251.2
# 8             522            227070     False         252.3
# 2             554            431566     False         479.5
# 4             536            665176     False         739.1
# 7             522            752724     False         836.4
# 0             542            791862     False         879.8
# 3             538            811304     False         901.4
# 9             543            859026     False         954.5
# 5             521            940405     False        1044.9
# 6             521            970102     False        1077.9
# OK to run as single batch:
# Empty DataFrame
# Columns: [event, split, num_rows, est_total_tokens, limit_used_%]
# Index: []
# Will be sharded (exceeds cap):
#                        event split  num_rows  est_total_tokens  limit_used_%
# 0      canada_wildfires_2016  test       445            226060         251.2
# 1   kaikoura_earthquake_2016  test       435            227070         252.3
# 2          cyclone_idai_2019  test       779            431566         479.5
# 3    hurricane_florence_2018  test      1241            665176         739.1
# 4       hurricane_maria_2017  test      1442            752724         836.4
# 5  california_wildfires_2018  test      1461            791862         879.8
# 6      hurricane_dorian_2019  test      1508            811304         901.4
# 7         kerala_floods_2018  test      1582            859026         954.5
# 8      hurricane_harvey_2017  test      1805            940405        1044.9
# 9        hurricane_irma_2017  test      1862            970102        1077.9

# %% [markdown]
# # 2) Run all datasets (sequentially)

# %%
def run_list_single(dflist: pd.DataFrame, rules_text: str, model: str, tag: str):
    """Run events that already fit under the cap using the normal runner."""
    results = []
    for _, row in dflist.iterrows():
        event, split, tsv = row["event"], row["split"], row["tsv"]
        print(f"\n=== Running (single) {event}/{split} ({model} | {tag}) ===")
        try:
            plan, preds, summary = run_experiment(
                dataset_path=tsv,
                rules=rules_text,
                model=model,
                tag=tag,
                dryrun_n=DRYRUN_N,
                poll_secs=POLL_SECS,
                out_root=OUT_ROOT,
                do_analysis=DO_ANALYSIS,
            )
            acc = summary.get("accuracy") if summary else float("nan")
            f1  = summary.get("macro_f1") if summary else float("nan")
            n   = summary.get("num_total_with_truth") if summary else len(preds)
            results.append({
                "event": event, "split": split,
                "run_dir": str(plan["dir"]),
                "predictions_csv": str(plan["predictions_csv"]),
                "macro_f1": f1, "accuracy": acc, "num_total": n,
                "mode": "single",
            })
        except Exception as e:
            print(f"[ERROR] {event}/{split}: {e}")
            results.append({
                "event": event, "split": split, "run_dir": "ERROR",
                "predictions_csv": "", "macro_f1": float("nan"),
                "accuracy": float("nan"), "num_total": 0, "mode": "single",
            })
    return pd.DataFrame(results)

def run_list_sharded(dflist: pd.DataFrame, token_df: pd.DataFrame, rules_text: str, model: str, tag: str):
    """Run events that exceed the cap using stratified shards. k is computed from token estimates."""
    results = []
    # Build a quick lookup: (event,split) -> est_total_tokens
    est_map = {(r.event, r.split): r.est_total_tokens for r in token_df.itertuples(index=False)}
    eff_cap = BATCH_TOKEN_LIMIT * SAFETY_MARGIN

    for _, row in dflist.iterrows():
        event, split, tsv = row["event"], row["split"], row["tsv"]
        est_tokens = est_map.get((event, split), None)
        # Conservative shard count: ceil(est / eff_cap). Min 2.
        k = max(2, math.ceil((est_tokens or (eff_cap + 1)) / eff_cap))
        print(f"\n=== Running (sharded x{k}) {event}/{split} ({model} | {tag}) ===")
        try:
            plan, preds, summary = run_experiment_sharded(
                dataset_path=tsv,
                rules=rules_text,
                model=model,
                tag=f"{tag}-sharded{k}",
                k_shards=k,
                temperature=0.0,
                poll_secs=POLL_SECS,
                out_root=OUT_ROOT,
                do_analysis=DO_ANALYSIS,
                analysis_subdir="analysis",  # merged analysis
            )
            acc = summary.get("accuracy") if summary else float("nan")
            f1  = summary.get("macro_f1") if summary else float("nan")
            n   = summary.get("num_total_with_truth") if summary else len(preds)
            results.append({
                "event": event, "split": split,
                "run_dir": str(plan["dir"]),
                "predictions_csv": str(plan["predictions_csv"]),
                "macro_f1": f1, "accuracy": acc, "num_total": n,
                "mode": f"sharded{k}",
            })
        except Exception as e:
            print(f"[ERROR] {event}/{split}: {e}")
            results.append({
                "event": event, "split": split, "run_dir": "ERROR",
                "predictions_csv": "", "macro_f1": float("nan"),
                "accuracy": float("nan"), "num_total": 0, "mode": f"sharded{k}",
            })
    return pd.DataFrame(results)

# %%
# --- Run singles with your normal key (optional context manager kept for parity)
with use_api_key_env("OPENAI_API_KEY_1"):
    print(">>> Using OPENAI_API_KEY_1")
    df_runs_single = run_list_single(df_fit, RULES, MODEL, tag=f"{TAG}-TIER1")

# --- Run sharded for the too-big ones (same key or another if you prefer)
# You can keep the same key; sharding is already controlling token usage.
with use_api_key_env("OPENAI_API_KEY_1"):
    if not df_too_big.empty:
        df_runs_sharded = run_list_sharded(df_too_big, token_index, RULES, MODEL, tag=f"{TAG}")
    else:
        df_runs_sharded = pd.DataFrame()
        print("No large datasets to shard.")

# 3) Save a small index of all runs
from datetime import datetime
idx_dir = Path(OUT_ROOT) / "_indexes"
idx_dir.mkdir(parents=True, exist_ok=True)
stamp = datetime.now().strftime("%Y%m%d-%H%M%S")

all_runs = pd.concat([df_runs_single, df_runs_sharded], ignore_index=True)
all_runs.to_csv(idx_dir / f"runs_{MODEL}_{TAG}_{stamp}.csv", index=False)
print("Saved run index at:", idx_dir)
display(all_runs)
# Out:
# >>> Using OPENAI_API_KEY_1
#
# === Running (sharded x3) canada_wildfires_2016/test (gpt-4o | modeS-gpt-4o-RULES2-filtered) ===
# [batch batch_690d3c3c7b9c819098ed3313aceee6d2] status = validating
# [batch batch_690d3c3c7b9c819098ed3313aceee6d2] status = completed
# [batch batch_690d3d6b75688190b85ac630630d34e0] status = validating
# [batch batch_690d3d6b75688190b85ac630630d34e0] status = completed
# [batch batch_690d3e9cbd048190b2f5cbd28edd8f9b] status = validating
# [batch batch_690d3e9cbd048190b2f5cbd28edd8f9b] status = completed
# Saved merged predictions to: runs\canada_wildfires_2016\test\gpt-4o\20251106-162422-modeS-gpt-4o-RULES2-filtered-sharded3\predictions.csv
# Macro-F1 (merged): 0.6668437182941035
#
# === Running (sharded x3) kaikoura_earthquake_2016/test (gpt-4o | modeS-gpt-4o-RULES2-filtered) ===
# [batch batch_690d3fcc5a548190b293bb3a0c617613] status = validating
# [batch batch_690d3fcc5a548190b293bb3a0c617613] status = completed
# [batch batch_690d40fb30348190ac7fedca86283fa6] status = validating
# [batch batch_690d40fb30348190ac7fedca86283fa6] status = completed
# [batch batch_690d422a41788190b8e013494c19a360] status = validating
# [batch batch_690d422a41788190b8e013494c19a360] status = completed
# Saved merged predictions to: runs\kaikoura_earthquake_2016\test\gpt-4o\20251106-163934-modeS-gpt-4o-RULES2-filtered-sharded3\predictions.csv
# Macro-F1 (merged): 0.7439535151993494
#
# === Running (sharded x6) cyclone_idai_2019/test (gpt-4o | modeS-gpt-4o-RULES2-filtered) ===
# [batch batch_690d435a4c1c819088eeb5ebf3cca25e] status = validating
# [batch batch_690d435a4c1c819088eeb5ebf3cca25e] status = completed
# [batch batch_690d44894cd0819098bc17fc3f65e446] status = validating
# [batch batch_690d44894cd0819098bc17fc3f65e446] status = completed
# [batch batch_690d45b8d9f08190a9b21f958d8a6b51] status = validating
# [batch batch_690d45b8d9f08190a9b21f958d8a6b51] status = completed
# [batch batch_690d46e834608190b836fe2d3323e90c] status = validating
# [batch batch_690d46e834608190b836fe2d3323e90c] status = completed
# [batch batch_690d4817396881908880b426103aa66e] status = validating
# [batch batch_690d4817396881908880b426103aa66e] status = completed
# [ERROR] cyclone_idai_2019/test: 502 Server Error: Bad Gateway for url: https://api.openai.com/v1/files/file-Gb7V7NkWdYowY9RpQs43qe/content
#
# === Running (sharded x9) hurricane_florence_2018/test (gpt-4o | modeS-gpt-4o-RULES2-filtered) ===
# [batch batch_690d4945caa88190a1fc20405abf3854] status = validating
# [batch batch_690d4945caa88190a1fc20405abf3854] status = completed
# [batch batch_690d4a754c38819092a2532cad53fbcb] status = validating
# [batch batch_690d4a754c38819092a2532cad53fbcb] status = in_progress
# [batch batch_690d4a754c38819092a2532cad53fbcb] status = in_progress
# [batch batch_690d4a754c38819092a2532cad53fbcb] status = in_progress
# [batch batch_690d4a754c38819092a2532cad53fbcb] status = completed
# [batch batch_690d4f2b33dc8190a83ffc700af41680] status = validating
# [batch batch_690d4f2b33dc8190a83ffc700af41680] status = completed
# [batch batch_690d505a3e2c819085e7c5738c9501ad] status = validating
# [batch batch_690d505a3e2c819085e7c5738c9501ad] status = completed
# [batch batch_690d51892da881908019a3b5ee65f77e] status = validating
# [batch batch_690d51892da881908019a3b5ee65f77e] status = completed
# [batch batch_690d52b8178c8190b15a5d925b01567a] status = validating
# [batch batch_690d52b8178c8190b15a5d925b01567a] status = completed
# [batch batch_690d53e78a788190b24014e317e2f2ed] status = validating
# [batch batch_690d53e78a788190b24014e317e2f2ed] status = completed
# [batch batch_690d5516a6e881908b571e05d628a4f5] status = validating
# [batch batch_690d5516a6e881908b571e05d628a4f5] status = in_progress
# [batch batch_690d5516a6e881908b571e05d628a4f5] status = in_progress
# [batch batch_690d5516a6e881908b571e05d628a4f5] status = in_progress
# [batch batch_690d5516a6e881908b571e05d628a4f5] status = completed
# [batch batch_690d59cc19d88190a9e42a5c2fcf1383] status = validating
# [batch batch_690d59cc19d88190a9e42a5c2fcf1383] status = completed
# Saved merged predictions to: runs\hurricane_florence_2018\test\gpt-4o\20251106-172000-modeS-gpt-4o-RULES2-filtered-sharded9\predictions.csv
# Macro-F1 (merged): 0.6930134831722143
#
# === Running (sharded x10) hurricane_maria_2017/test (gpt-4o | modeS-gpt-4o-RULES2-filtered) ===
# [batch batch_690d5afb7a1c81909fe55d7609d5cc90] status = validating
# [batch batch_690d5afb7a1c81909fe55d7609d5cc90] status = completed
# [batch batch_690d5c29e398819085502ce025f7b117] status = validating
# [batch batch_690d5c29e398819085502ce025f7b117] status = completed
# [batch batch_690d5d58bd848190bc5528c7328ff9c9] status = validating
# [batch batch_690d5d58bd848190bc5528c7328ff9c9] status = completed
# [batch batch_690d5e8732c88190988e9ccbe91022ee] status = validating
# [batch batch_690d5e8732c88190988e9ccbe91022ee] status = completed
# [batch batch_690d5fb76e38819086be8ef22cfd50d3] status = validating
# [batch batch_690d5fb76e38819086be8ef22cfd50d3] status = completed
# [batch batch_690d60e6c0748190a703b36b178e63d5] status = validating
# [batch batch_690d60e6c0748190a703b36b178e63d5] status = completed
# [batch batch_690d62155db48190b40da2601b9739e6] status = validating
# [batch batch_690d62155db48190b40da2601b9739e6] status = completed
# [batch batch_690d6344c0f881909447d029c682f9b5] status = validating
# [batch batch_690d6344c0f881909447d029c682f9b5] status = completed
# [batch batch_690d6473fee08190ba75f42aadf252e6] status = validating
# [batch batch_690d6473fee08190ba75f42aadf252e6] status = in_progress
# [batch batch_690d6473fee08190ba75f42aadf252e6] status = in_progress
# [batch batch_690d6473fee08190ba75f42aadf252e6] status = in_progress
# [batch batch_690d6473fee08190ba75f42aadf252e6] status = completed
# [batch batch_690d6929d8348190916a73563fca36be] status = validating
# [batch batch_690d6929d8348190916a73563fca36be] status = completed
# Saved merged predictions to: runs\hurricane_maria_2017\test\gpt-4o\20251106-183533-modeS-gpt-4o-RULES2-filtered-sharded10\predictions.csv
# Macro-F1 (merged): 0.6240458816805158
#
# === Running (sharded x10) california_wildfires_2018/test (gpt-4o | modeS-gpt-4o-RULES2-filtered) ===
# [batch batch_690d6a59f43c8190976d13da373a9fac] status = validating
# [batch batch_690d6a59f43c8190976d13da373a9fac] status = completed
# [batch batch_690d6b89b6cc819088531cc2bcce75db] status = validating
# [batch batch_690d6b89b6cc819088531cc2bcce75db] status = completed
# [batch batch_690d6cb92aac81909ecf245be25b4b33] status = validating
# [batch batch_690d6cb92aac81909ecf245be25b4b33] status = completed
# [batch batch_690d6de7d74c819096b73b8cf9b4e041] status = validating
# [batch batch_690d6de7d74c819096b73b8cf9b4e041] status = completed
# [batch batch_690d6f16d558819099231c025226fee6] status = validating
# [batch batch_690d6f16d558819099231c025226fee6] status = completed
# [batch batch_690d7045e5f48190a9d09ea0c0c71b14] status = validating
# [batch batch_690d7045e5f48190a9d09ea0c0c71b14] status = completed
# [batch batch_690d717496e08190a5f31568e0be8c9d] status = validating
# [batch batch_690d717496e08190a5f31568e0be8c9d] status = completed
# [batch batch_690d72a39ef081908851260d18ff73b7] status = validating
# [batch batch_690d72a39ef081908851260d18ff73b7] status = completed
# [batch batch_690d73d303b08190a3866fc04599bc4d] status = validating
# [batch batch_690d73d303b08190a3866fc04599bc4d] status = completed
# [batch batch_690d7501e00881908a4ba29257b3aee8] status = validating
# [batch batch_690d7501e00881908a4ba29257b3aee8] status = completed
# Saved merged predictions to: runs\california_wildfires_2018\test\gpt-4o\20251106-194112-modeS-gpt-4o-RULES2-filtered-sharded10\predictions.csv
# Macro-F1 (merged): 0.6142849658599281
#
# === Running (sharded x11) hurricane_dorian_2019/test (gpt-4o | modeS-gpt-4o-RULES2-filtered) ===
# [batch batch_690d7632422c819082a20485240ef051] status = validating
# [batch batch_690d7632422c819082a20485240ef051] status = completed
# [batch batch_690d7761fe20819083de4995950011d4] status = validating
# [batch batch_690d7761fe20819083de4995950011d4] status = in_progress
# [batch batch_690d7761fe20819083de4995950011d4] status = in_progress
# [batch batch_690d7761fe20819083de4995950011d4] status = in_progress
# [batch batch_690d7761fe20819083de4995950011d4] status = completed
# [batch batch_690d7c23f44481909e0810ad5ac942fb] status = validating
# [batch batch_690d7c23f44481909e0810ad5ac942fb] status = in_progress
# [batch batch_690d7c23f44481909e0810ad5ac942fb] status = in_progress
# [batch batch_690d7c23f44481909e0810ad5ac942fb] status = in_progress
# [batch batch_690d7c23f44481909e0810ad5ac942fb] status = completed
# [batch batch_690d80d939188190a120b08b991f9aad] status = validating

# %% [markdown]
# # Other experiments

# %%
from pathlib import Path
import math
import pandas as pd
from dotenv import load_dotenv; load_dotenv()

from humaidclf import run_experiment
from humaidclf import build_token_index               # token budgeting (sampling-based)
from humaidclf import run_experiment_sharded          # NEW: stratified sharded runner
from humaidclf.batch import use_api_key_env           # (optional) keep key switcher
from rules import RULES_1

# --- config ---
BASE = Path("Dataset/HumAID")
SPLITS = ["test"]             # or ["train","dev","test"]
MODEL = "gpt-4-0613"
RULES = RULES_1
TAG = "modeS-gpt-41-RULES1-filtered"
DRYRUN_N = 20
POLL_SECS = 300
DO_ANALYSIS = True
OUT_ROOT = "runs"

K = 10  # number of stratified shards

with use_api_key_env("OPENAI_API_KEY"):
    plan, preds, summary = run_experiment_sharded(
        dataset_path=str(BASE / "canada_wildfires_2016" / "canada_wildfires_2016_test.tsv"),
        rules=RULES,
        model=MODEL,
        tag=f"{TAG}-sharded{K}",
        k_shards=K,
        temperature=0.0,
        poll_secs=POLL_SECS,
        out_root=OUT_ROOT,
        do_analysis=DO_ANALYSIS,
        analysis_subdir="analysis",
    )

summary

# %%
from pathlib import Path
import pandas as pd
from dotenv import load_dotenv; load_dotenv()

from humaidclf import run_experiment_sharded
from humaidclf.batch import use_api_key_env
from rules import RULES_1

# --- config ---
BASE = Path("Dataset/HumAID")
SPLITS = ["test"]             # or ["train","dev","test"]
MODEL = "gpt-4.1"
RULES = RULES_1
TAG = "modeS-gpt-41-RULES1-filtered"
DRYRUN_N = 20
POLL_SECS = 300
DO_ANALYSIS = True
OUT_ROOT = "runs"
K = 10  # number of stratified shards

with use_api_key_env("OPENAI_API_KEY"):
    plan, preds, summary = run_experiment_sharded(
        dataset_path=str(BASE / "hurricane_harvey_2017" / "hurricane_harvey_2017_test.tsv"),
        rules=RULES,
        model=MODEL,
        tag=f"{TAG}-sharded{K}",
        k_shards=K,
        temperature=0.0,
        poll_secs=POLL_SECS,
        out_root=OUT_ROOT,
        do_analysis=DO_ANALYSIS,
        analysis_subdir="analysis",
    )

summary

# %%
from pathlib import Path
import pandas as pd
from dotenv import load_dotenv; load_dotenv()

from humaidclf import run_experiment_sharded
from humaidclf.batch import use_api_key_env
from rules import RULES_1

# --- config ---
BASE = Path("Dataset/HumAID")
SPLITS = ["test"]             # or ["train","dev","test"]
MODEL = "gpt-4.1"
RULES = RULES_1
TAG = "modeS-gpt-41-RULES1-filtered"
DRYRUN_N = 20
POLL_SECS = 300
DO_ANALYSIS = True
OUT_ROOT = "runs"
K = 10  # number of stratified shards

with use_api_key_env("OPENAI_API_KEY"):
    plan, preds, summary = run_experiment_sharded(
        dataset_path=str(BASE / "hurricane_irma_2017" / "hurricane_irma_2017_test.tsv"),
        rules=RULES,
        model=MODEL,
        tag=f"{TAG}-sharded{K}",
        k_shards=K,
        temperature=0.0,
        poll_secs=POLL_SECS,
        out_root=OUT_ROOT,
        do_analysis=DO_ANALYSIS,
        analysis_subdir="analysis",
    )

summary
